# %%
import numpy as np 
import pandas as pd 
import matplotlib 
import matplotlib.pyplot as plt

# %%
car_prices = pd.read_csv("C:\\Users\\HP\\Documents\\kagglex-cohort4\\train.csv")
car_prices.head()
# Out:
#    id    brand          model  model_year  milage fuel_type  \
# 0   0     Ford   F-150 Lariat        2018   74349  Gasoline
# 1   1      BMW          335 i        2007   80000  Gasoline
# 2   2   Jaguar      XF Luxury        2009   91491  Gasoline
# 3   3      BMW   X7 xDrive40i        2022    2437    Hybrid
# 4   4  Pontiac  Firebird Base        2001  111000  Gasoline
#
#                                               engine  \
# 0      375.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 1  300.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       300.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 3  335.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 4      200.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col       accident clean_title  \
# 0                    10-Speed A/T    Blue    Gray  None reported         Yes
# 1                     6-Speed M/T   Black   Black  None reported         Yes
# ...

# %%
car_prices.drop(["id"], axis=1, inplace=True)

# %%
car_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54273 entries, 0 to 54272
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         54273 non-null  object
#  1   model         54273 non-null  object
#  2   model_year    54273 non-null  int64
#  3   milage        54273 non-null  int64
#  4   fuel_type     54273 non-null  object
#  5   engine        54273 non-null  object
#  6   transmission  54273 non-null  object
#  7   ext_col       54273 non-null  object
#  8   int_col       54273 non-null  object
#  9   accident      54273 non-null  object
#  10  clean_title   54273 non-null  object
#  11  price         54273 non-null  int64
# dtypes: int64(3), object(9)
# memory usage: 5.0+ MB

# %%
car_prices.describe()
# Out:
#          model_year         milage         price
# count  54273.000000   54273.000000  5.427300e+04
# mean    2015.091979   72746.175667  3.921844e+04
# std        5.588909   50469.490448  7.282634e+04
# min     1974.000000     100.000000  2.000000e+03
# 25%     2012.000000   32268.000000  1.550000e+04
# 50%     2016.000000   66107.000000  2.800000e+04
# 75%     2019.000000  102000.000000  4.500000e+04
# max     2024.000000  405000.000000  2.954083e+06

# %%
car_prices["brand"].unique()
# Out:
# array(['Ford', 'BMW', 'Jaguar', 'Pontiac', 'Acura', 'Audi', 'GMC',
#        'Maserati', 'Chevrolet', 'Porsche', 'Mercedes-Benz', 'Tesla',
#        'Lexus', 'Kia', 'Lincoln', 'Dodge', 'Volkswagen', 'Land',
#        'Cadillac', 'Mazda', 'RAM', 'Subaru', 'Hyundai', 'MINI', 'Jeep',
#        'Honda', 'Hummer', 'Nissan', 'Toyota', 'Volvo', 'Genesis',
#        'Mitsubishi', 'Buick', 'INFINITI', 'McLaren', 'Scion',
#        'Lamborghini', 'Bentley', 'Suzuki', 'Ferrari', 'Alfa',
#        'Rolls-Royce', 'Chrysler', 'Aston', 'Rivian', 'Lotus', 'Saturn',
#        'Lucid', 'Mercury', 'Maybach', 'FIAT', 'Plymouth', 'Bugatti'],
#       dtype=object)

# %%
len(car_prices["model"].unique())
# Out:
# 1827

# %%
len(car_prices["fuel_type"].unique())
# Out:
# 7

# %%
car_prices["transmission"].unique()
# Out:
# array(['10-Speed A/T', '6-Speed M/T', '6-Speed A/T',
#        'Transmission w/Dual Shift Mode', 'A/T', '5-Speed M/T',
#        '7-Speed A/T', '5-Speed A/T', '8-Speed A/T',
#        'Transmission Overdrive Switch', '9-Speed Automatic',
#        '7-Speed M/T', '10-Speed Automatic', '6-Speed Automatic', 'M/T',
#        '5-Speed Automatic', 'CVT Transmission', '9-Speed A/T',
#        '8-Speed Automatic', '4-Speed A/T', 'Automatic', '1-Speed A/T',
#        '8-Speed Automatic with Auto-Shift', '7-Speed DCT Automatic',
#        'Automatic CVT', '7-Speed Automatic',
#        '7-Speed Automatic with Auto-Shift', '4-Speed Automatic',
#        '6-Speed Automatic with Auto-Shift', '6-Speed Manual',
#        '7-Speed Manual',
#        '6-Speed Electronically Controlled Automatic with O',
#        '1-Speed Automatic', '10-Speed Automatic with Overdrive',
#        '8-Speed Manual', '2-Speed A/T', 'CVT-F', '–', 'F',
#        '9-Speed Automatic with Auto-Shift', '7-Speed', 'Variable',
# ...

# %%
len(car_prices["ext_col"].unique())
# Out:
# 260

# %%
car_prices["fuel_type"].unique()
# Out:
# array(['Gasoline', 'Hybrid', 'E85 Flex Fuel', 'Diesel', '–',
#        'Plug-In Hybrid', 'not supported'], dtype=object)

# %%
car_prices["accident"].unique()
# Out:
# array(['None reported', 'At least 1 accident or damage reported'],
#       dtype=object)

# %%
plt.figure(figsize=(10, 5))
plt.scatter(car_prices["milage"], car_prices["price"])
# plt.plot(x, np.cos(x))
plt.show()

# %%
value = '–'
 
result1 = car_prices.isin([value]).any()
print(result1)
# Out:
# brand           False
# model           False
# model_year      False
# milage          False
# fuel_type        True
# engine           True
# transmission     True
# ext_col          True
# int_col          True
# accident        False
# clean_title     False
# price           False
# dtype: bool

# %%
# Replace the '–' with the most occuring or the mean value.

car_prices['fuel_type'].replace(to_replace='–', value=car_prices['fuel_type'].mode, inplace=True)
car_prices['engine'].replace(to_replace='–', value=car_prices['engine'].mode, inplace=True)
car_prices['transmission'].replace(to_replace='–', value=car_prices['transmission'].mode, inplace=True)
car_prices['ext_col'].replace(to_replace='–', value=car_prices['ext_col'].mode, inplace=True)
car_prices['int_col'].replace(to_replace='–', value=car_prices['int_col'].mode, inplace=True)

# %%
value = '–'
 
result1 = car_prices.isin([value]).any()
print(result1)
# Out:
# brand           False
# model           False
# model_year      False
# milage          False
# fuel_type       False
# engine          False
# transmission    False
# ext_col         False
# int_col         False
# accident        False
# clean_title     False
# price           False
# dtype: bool

# %%
len(car_prices["ext_col"].unique())
# Out:
# 260

# %%
car_prices.drop("engine", axis=1, inplace=True)

# %%
car_prices.head()
# Out:
#      brand          model  model_year  milage fuel_type  \
# 0     Ford   F-150 Lariat        2018   74349  Gasoline
# 1      BMW          335 i        2007   80000  Gasoline
# 2   Jaguar      XF Luxury        2009   91491  Gasoline
# 3      BMW   X7 xDrive40i        2022    2437    Hybrid
# 4  Pontiac  Firebird Base        2001  111000  Gasoline
#
#                      transmission ext_col int_col       accident clean_title  \
# 0                    10-Speed A/T    Blue    Gray  None reported         Yes
# 1                     6-Speed M/T   Black   Black  None reported         Yes
# 2                     6-Speed A/T  Purple   Beige  None reported         Yes
# 3  Transmission w/Dual Shift Mode    Gray   Brown  None reported         Yes
# 4                             A/T   White   Black  None reported         Yes
#
#    price
# 0  11000
# 1   8250
# 2  15000
# 3  63500
# 4   7850

# %%
car_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54273 entries, 0 to 54272
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         54273 non-null  object
#  1   model         54273 non-null  object
#  2   model_year    54273 non-null  int64
#  3   milage        54273 non-null  int64
#  4   fuel_type     54273 non-null  object
#  5   transmission  54273 non-null  object
#  6   ext_col       54273 non-null  object
#  7   int_col       54273 non-null  object
#  8   accident      54273 non-null  object
#  9   clean_title   54273 non-null  object
#  10  price         54273 non-null  int64
# dtypes: int64(3), object(8)
# memory usage: 4.6+ MB

# %%
car_model=car_prices["model"].unique()

# %%
for i in car_model:
    print(i, car_prices["model"].value_counts()[i])
# Out:
# F-150 Lariat 496
# 335 i 229
# XF Luxury 21
# X7 xDrive40i 180
# Firebird Base 16
# Integra LS 13
# S5 3.0T Prestige 72
# Acadia SLT-1 56
# A3 2.0T Tech Premium 54
# MDX Technology 17
# Quattroporte S Q4 GranLusso 15
# Tahoe Premier 57
# Cayenne S 112
# Q7 55 Prestige 25
# C-Class C 300 4MATIC Sport 185
# Terrain SLT-1 58
# Model 3 Long Range 15
# LS 460 Base 53
# Sierra 2500 SLE 7
# Telluride LX 4
# Terrain SLE 13
# Transit-350 XLT 127
# MKZ Base 117
# Mustang EcoBoost Premium 109
# Challenger GT 5
# Corvette Z06 85
# Expedition Max XLT 60
# A7 Premium 15
# Jetta 1.4T SE 29
# F-350 King Ranch 11
# Transit Connect XLT 117
# M340 i xDrive 30
# Sierra 1500 SLT 130
# A4 2.0T Premium Plus quattro 39
# Rover Range Rover Sport HSE Dynamic 57
# Escalade ESV Platinum 185
# Thunderbird Premium 13
# CX-30 Premium Package 52
# 911 R 9
# 1500 Rebel 97
# Yukon XL SLT 140
# Rover Range Rover P530 SE LWB 7 Seat 51
# A4 3.2 Premium Plus quattro 8
# Crosstrek 2.0i Limited 20
# Challenger SXT 14
# ...

# %%
# Deciding the initial threshold to be 0.5% of the initial dataset size

total_instances = car_prices.shape[0]
threshold = total_instances*0.002
print("The minimum count threshold is " +str(threshold))
# Out:
# The minimum count threshold is 108.546

# %%
obj_columns = list(car_prices.select_dtypes(include=['object']).columns)
# obj_columns.remove('tHE TARGET COLUMN') No need to remove the target column
car_prices = car_prices.apply(lambda x: x.mask(x.map(x.value_counts())<threshold, "Rare") if x.name in obj_columns else x)

# %%
# car_model=car_prices["model"].unique()

# for i in car_model:
#     print(i, car_prices["model"].value_counts()[i])

# obj_columns = list(car_prices.select_dtypes(include=['object']).columns)
# # obj_columns.remove('tHE TARGET COLUMN') #No need to remove the target column
# car_prices = car_prices.apply(lambda x: x.mask(x.map(x.value_counts())<threshold, "Rare") if x.name in obj_columns)

# %%
car_prices.head()
# Out:
#      brand         model  model_year  milage fuel_type  \
# 0     Ford  F-150 Lariat        2018   74349  Gasoline
# 1      BMW         335 i        2007   80000  Gasoline
# 2   Jaguar          Rare        2009   91491  Gasoline
# 3      BMW  X7 xDrive40i        2022    2437    Hybrid
# 4  Pontiac          Rare        2001  111000  Gasoline
#
#                      transmission ext_col int_col       accident clean_title  \
# 0                    10-Speed A/T    Blue    Gray  None reported         Yes
# 1                     6-Speed M/T   Black   Black  None reported         Yes
# 2                     6-Speed A/T    Rare   Beige  None reported         Yes
# 3  Transmission w/Dual Shift Mode    Gray   Brown  None reported         Yes
# 4                             A/T   White   Black  None reported         Yes
#
#    price
# 0  11000
# 1   8250
# 2  15000
# 3  63500
# 4   7850

# %%
car_model_after=car_prices["model"].unique()

# %%
for i in car_model_after:
    print(i, car_prices["model"].value_counts()[i])
# Out:
# F-150 Lariat 496
# 335 i 229
# Rare 33890
# X7 xDrive40i 180
# Cayenne S 112
# C-Class C 300 4MATIC Sport 185
# Transit-350 XLT 127
# MKZ Base 117
# Mustang EcoBoost Premium 109
# Transit Connect XLT 117
# Sierra 1500 SLT 130
# Escalade ESV Platinum 185
# Yukon XL SLT 140
# 528 i xDrive 138
# Rover Range Rover Sport HSE 174
# Wrangler Unlimited Sport 358
# Wrangler Sport 350
# F-250 XLT 211
# E-Class E 350 4MATIC 397
# M3 Base 682
# Fusion SE 122
# E-Class E 350 388
# Mustang GT Premium 466
# X6 M Base 296
# F-150 XLT 780
# Corvette Stingray w/3LT 174
# A4 2.0T Premium 164
# Tundra SR5 127
# X3 xDrive30i 174
# X6 xDrive40i 179
# Expedition Max Limited 130
# F-250 Lariat 289
# 435 i 142
# Land Cruiser Base 124
# X5 xDrive40i 349
# Suburban LT 225
# GX 470 Base 145
# Tahoe LTZ 144
# SL-Class SL 550 163
# X5 xDrive35i 615
# Highlander XLE 196
# M6 Base 158
# Ram 1500 ST 173
# G-Class G 550 4MATIC 232
# S4 3.0T Premium Plus 140
# Wrangler Unlimited Sahara 186
# Q5 2.0T Premium Plus 197
# ...

# %%
car_prices["int_col"].iloc[20]
# Out:
# 'Jet Black'

# %%
len(car_prices["ext_col"].unique())
# Out:
# 14

# %%
for i in car_extcol:
    print(i, car_prices["ext_col"].value_counts()[i])
# Out:
# Blue 4668
# Black 15078
# Rare 2187
# Gray 7909
# White 13422
# Red 3013
# Silver 5161
# Green 763
# Orange 328
# Beige 455
# Gold 484
# Brown 386
# Yellow 306
# Agate Black Metallic 113

# %%
len(car_prices["int_col"].unique())
# Out:
# 13
